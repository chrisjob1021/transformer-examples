# %%
import torch
from utils import apply_rope

batch_size = 1
dimension = 16
per_head_dim = 8
n_heads = 2
seq_len = 10

x = torch.randn(batch_size, seq_len, dimension)
q_proj = x.view(batch_size, seq_len, n_heads, per_head_dim).transpose(1, 2)
x = apply_rope(q_proj, past_seq_len=0, freq=10000.0, visualize=True, debug=True)
# Out:
# theta.shape torch.Size([10, 4])
# theta tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.0000e+00, 1.0000e-01, 1.0000e-02, 1.0000e-03],
#         [2.0000e+00, 2.0000e-01, 2.0000e-02, 2.0000e-03],
#         [3.0000e+00, 3.0000e-01, 3.0000e-02, 3.0000e-03],
#         [4.0000e+00, 4.0000e-01, 4.0000e-02, 4.0000e-03],
#         [5.0000e+00, 5.0000e-01, 5.0000e-02, 5.0000e-03],
#         [6.0000e+00, 6.0000e-01, 6.0000e-02, 6.0000e-03],
#         [7.0000e+00, 7.0000e-01, 7.0000e-02, 7.0000e-03],
#         [8.0000e+00, 8.0000e-01, 8.0000e-02, 8.0000e-03],
#         [9.0000e+00, 9.0000e-01, 9.0000e-02, 9.0000e-03]])
# cos_theta.shape torch.Size([1, 1, 10, 4])
# cos_theta tensor([[[[ 1.0000,  1.0000,  1.0000,  1.0000],
#           [ 0.5403,  0.9950,  0.9999,  1.0000],
#           [-0.4161,  0.9801,  0.9998,  1.0000],
#           [-0.9900,  0.9553,  0.9996,  1.0000],
#           [-0.6536,  0.9211,  0.9992,  1.0000],
#           [ 0.2837,  0.8776,  0.9988,  1.0000],
#           [ 0.9602,  0.8253,  0.9982,  1.0000],
#           [ 0.7539,  0.7648,  0.9976,  1.0000],
#           [-0.1455,  0.6967,  0.9968,  1.0000],
#           [-0.9111,  0.6216,  0.9960,  1.0000]]]])
# sin_theta.shape torch.Size([1, 1, 10, 4])
# sin_theta tensor([[[[ 0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.8415,  0.0998,  0.0100,  0.0010],
#           [ 0.9093,  0.1987,  0.0200,  0.0020],
#           [ 0.1411,  0.2955,  0.0300,  0.0030],
#           [-0.7568,  0.3894,  0.0400,  0.0040],
#           [-0.9589,  0.4794,  0.0500,  0.0050],
#           [-0.2794,  0.5646,  0.0600,  0.0060],
#           [ 0.6570,  0.6442,  0.0699,  0.0070],
#           [ 0.9894,  0.7174,  0.0799,  0.0080],
#           [ 0.4121,  0.7833,  0.0899,  0.0090]]]])
#
# Math equation for position 0:
# Dimension 0:
# x_rotated_even = 0.0031 * 1.0000 - 0.9486 * 0.0000 = 0.0031
# x_rotated_odd = 0.0031 * 0.0000 + 0.9486 * 1.0000 = 0.9486
# Dimension 1:
# x_rotated_even = 0.2332 * 1.0000 - -0.1706 * 0.0000 = 0.2332
# x_rotated_odd = 0.2332 * 0.0000 + -0.1706 * 1.0000 = -0.1706
#
# Math equation for position 1:
# Dimension 0:
# x_rotated_even = -0.7440 * 0.5403 - -0.3269 * 0.8415 = -0.1270
# x_rotated_odd = -0.7440 * 0.8415 + -0.3269 * 0.5403 = -0.8027
# Dimension 1:
# x_rotated_even = 1.7220 * 0.9950 - -0.0107 * 0.0998 = 1.7144
# x_rotated_odd = 1.7220 * 0.0998 + -0.0107 * 0.9950 = 0.1612
#
# Position 0 dimensions:
# Dimension 0: Original=(0.0031, 0.9486), Rotated=(0.0031, 0.9486)
# Dimension 1: Original=(0.2332, -0.1706), Rotated=(0.2332, -0.1706)
# Dimension 2: Original=(0.8100, 1.7452), Rotated=(0.8100, 1.7452)
# Dimension 3: Original=(-0.2549, -1.3572), Rotated=(-0.2549, -1.3572)
# Position 1 dimensions:
# Dimension 0: Original=(-0.7440, -0.3269), Rotated=(-0.1270, -0.8027)
# Dimension 1: Original=(1.7220, -0.0107), Rotated=(1.7144, 0.1612)
# Dimension 2: Original=(0.1771, 0.6451), Rotated=(0.1707, 0.6468)
# Dimension 3: Original=(0.6108, -0.6412), Rotated=(0.6115, -0.6406)
# Position 2 dimensions:
# Dimension 0: Original=(-1.5626, -1.4452), Rotated=(1.9644, -0.8195)
# Dimension 1: Original=(-1.3578, -0.0556), Rotated=(-1.3197, -0.3242)
# Dimension 2: Original=(-0.1983, 0.7525), Rotated=(-0.2133, 0.7484)
# Dimension 3: Original=(-1.0121, -0.2171), Rotated=(-1.0117, -0.2192)
# Position 3 dimensions:
# Dimension 0: Original=(-1.8447, -0.4212), Rotated=(1.8857, 0.1566)
# Dimension 1: Original=(-1.4596, -1.5633), Rotated=(-0.9325, -1.9249)
# Dimension 2: Original=(-0.0669, 0.5229), Rotated=(-0.0825, 0.5206)
# Dimension 3: Original=(-0.5505, 1.7307), Rotated=(-0.5557, 1.7290)
# Position 4 dimensions:
# Dimension 0: Original=(1.5446, 1.1509), Rotated=(-0.1386, -1.9213)
# Dimension 1: Original=(0.7842, -0.8153), Rotated=(1.0398, -0.4455)
# Dimension 2: Original=(-0.9718, 0.5820), Rotated=(-0.9943, 0.5427)
# Dimension 3: Original=(0.5635, -0.6000), Rotated=(0.5659, -0.5978)
# Position 5 dimensions:
# Dimension 0: Original=(0.8221, -1.2143), Rotated=(-0.9312, -1.1328)
# Dimension 1: Original=(-0.1791, 1.4816), Rotated=(-0.8675, 1.2144)
# Dimension 2: Original=(-0.7337, -0.7584), Rotated=(-0.6949, -0.7941)
# Dimension 3: Original=(-0.3272, 1.7981), Rotated=(-0.3362, 1.7964)
# Position 6 dimensions:
# Dimension 0: Original=(0.0784, 0.7062), Rotated=(0.2726, 0.6562)
# Dimension 1: Original=(-1.8679, -0.0105), Rotated=(-1.5357, -1.0634)
# Dimension 2: Original=(-0.1555, 0.1074), Rotated=(-0.1616, 0.0979)
# Dimension 3: Original=(-1.9853, 0.1124), Rotated=(-1.9859, 0.1004)
# Position 7 dimensions:
# Dimension 0: Original=(0.7639, -0.1717), Rotated=(0.6887, 0.3724)
# Dimension 1: Original=(-0.3243, -0.6028), Rotated=(0.1403, -0.6700)
# Dimension 2: Original=(-1.2008, -0.3753), Rotated=(-1.1716, -0.4584)
# Dimension 3: Original=(0.3282, 0.1876), Rotated=(0.3269, 0.1899)
# Position 8 dimensions:
# Dimension 0: Original=(0.2438, 0.5610), Rotated=(-0.5905, 0.1596)
# Dimension 1: Original=(-1.1293, -1.4648), Rotated=(0.2640, -1.8307)
# Dimension 2: Original=(-0.6657, -0.4632), Rotated=(-0.6266, -0.5149)
# Dimension 3: Original=(-0.9503, 0.1586), Rotated=(-0.9515, 0.1510)
# Position 9 dimensions:
# Dimension 0: Original=(0.5598, 1.1995), Rotated=(-1.0044, -0.8622)
# Dimension 1: Original=(-0.6129, -0.1186), Rotated=(-0.2881, -0.5538)
# Dimension 2: Original=(-0.0925, 1.0785), Rotated=(-0.1890, 1.0658)
# Dimension 3: Original=(0.5417, -0.7471), Rotated=(0.5484, -0.7422)
