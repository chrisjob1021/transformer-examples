# %%
import torch
from utils import apply_rope

batch_size = 1
dimension = 16
per_head_dim = 8
n_heads = 2
seq_len = 10

x = torch.randn(batch_size, seq_len, dimension)
q_proj = x.view(batch_size, seq_len, n_heads, per_head_dim).transpose(1, 2)
x = apply_rope(q_proj, past_seq_len=0, freq=10000.0, visualize=True, debug=True)
# Out:
# theta.shape torch.Size([10, 4])
# theta tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [1.0000e+00, 1.0000e-01, 1.0000e-02, 1.0000e-03],
#         [2.0000e+00, 2.0000e-01, 2.0000e-02, 2.0000e-03],
#         [3.0000e+00, 3.0000e-01, 3.0000e-02, 3.0000e-03],
#         [4.0000e+00, 4.0000e-01, 4.0000e-02, 4.0000e-03],
#         [5.0000e+00, 5.0000e-01, 5.0000e-02, 5.0000e-03],
#         [6.0000e+00, 6.0000e-01, 6.0000e-02, 6.0000e-03],
#         [7.0000e+00, 7.0000e-01, 7.0000e-02, 7.0000e-03],
#         [8.0000e+00, 8.0000e-01, 8.0000e-02, 8.0000e-03],
#         [9.0000e+00, 9.0000e-01, 9.0000e-02, 9.0000e-03]])
# cos_theta.shape torch.Size([1, 1, 10, 4])
# cos_theta tensor([[[[ 1.0000,  1.0000,  1.0000,  1.0000],
#           [ 0.5403,  0.9950,  0.9999,  1.0000],
#           [-0.4161,  0.9801,  0.9998,  1.0000],
#           [-0.9900,  0.9553,  0.9996,  1.0000],
#           [-0.6536,  0.9211,  0.9992,  1.0000],
#           [ 0.2837,  0.8776,  0.9988,  1.0000],
#           [ 0.9602,  0.8253,  0.9982,  1.0000],
#           [ 0.7539,  0.7648,  0.9976,  1.0000],
#           [-0.1455,  0.6967,  0.9968,  1.0000],
#           [-0.9111,  0.6216,  0.9960,  1.0000]]]])
# sin_theta.shape torch.Size([1, 1, 10, 4])
# sin_theta tensor([[[[ 0.0000,  0.0000,  0.0000,  0.0000],
#           [ 0.8415,  0.0998,  0.0100,  0.0010],
#           [ 0.9093,  0.1987,  0.0200,  0.0020],
#           [ 0.1411,  0.2955,  0.0300,  0.0030],
#           [-0.7568,  0.3894,  0.0400,  0.0040],
#           [-0.9589,  0.4794,  0.0500,  0.0050],
#           [-0.2794,  0.5646,  0.0600,  0.0060],
#           [ 0.6570,  0.6442,  0.0699,  0.0070],
#           [ 0.9894,  0.7174,  0.0799,  0.0080],
#           [ 0.4121,  0.7833,  0.0899,  0.0090]]]])
#
# Math equation for position 0:
# Dimension 0:
# x_rotated_even = -0.1244 * 1.0000 - 0.5792 * 0.0000 = -0.1244
# x_rotated_odd = -0.1244 * 0.0000 + 0.5792 * 1.0000 = 0.5792
# Dimension 1:
# x_rotated_even = -0.6253 * 1.0000 - -0.5826 * 0.0000 = -0.6253
# x_rotated_odd = -0.6253 * 0.0000 + -0.5826 * 1.0000 = -0.5826
#
# Math equation for position 1:
# Dimension 0:
# x_rotated_even = -0.9961 * 0.5403 - -1.4155 * 0.8415 = 0.6529
# x_rotated_odd = -0.9961 * 0.8415 + -1.4155 * 0.5403 = -1.6030
# Dimension 1:
# x_rotated_even = 0.5142 * 0.9950 - -0.4635 * 0.0998 = 0.5579
# x_rotated_odd = 0.5142 * 0.0998 + -0.4635 * 0.9950 = -0.4098
#
# Position 0 dimensions:
# Dimension 0: Original=(-0.1244, 0.5792), Rotated=(-0.1244, 0.5792)
# Dimension 1: Original=(-0.6253, -0.5826), Rotated=(-0.6253, -0.5826)
# Dimension 2: Original=(-0.6717, 0.0374), Rotated=(-0.6717, 0.0374)
# Dimension 3: Original=(1.2529, 0.2915), Rotated=(1.2529, 0.2915)
# Position 1 dimensions:
# Dimension 0: Original=(-0.9961, -1.4155), Rotated=(0.6529, -1.6030)
# Dimension 1: Original=(0.5142, -0.4635), Rotated=(0.5579, -0.4098)
# Dimension 2: Original=(-0.4687, -0.9328), Rotated=(-0.4594, -0.9374)
# Dimension 3: Original=(1.7003, 1.0428), Rotated=(1.6992, 1.0445)
# Position 2 dimensions:
# Dimension 0: Original=(0.3294, -1.9190), Rotated=(1.6079, 1.0981)
# Dimension 1: Original=(-0.6899, -0.4387), Rotated=(-0.5890, -0.5671)
# Dimension 2: Original=(-0.6855, -0.1185), Rotated=(-0.6830, -0.1322)
# Dimension 3: Original=(1.0283, -0.6591), Rotated=(1.0296, -0.6571)
# Position 3 dimensions:
# Dimension 0: Original=(0.5070, -1.2188), Rotated=(-0.3299, 1.2781)
# Dimension 1: Original=(-0.9518, 1.2070), Rotated=(-1.2660, 0.8718)
# Dimension 2: Original=(-1.0139, -0.1445), Rotated=(-1.0092, -0.1749)
# Dimension 3: Original=(0.1384, 0.3323), Rotated=(0.1374, 0.3327)
# Position 4 dimensions:
# Dimension 0: Original=(0.8285, -0.0613), Rotated=(-0.5879, -0.5870)
# Dimension 1: Original=(0.3482, -3.2538), Rotated=(1.5878, -2.8614)
# Dimension 2: Original=(0.3122, -0.1798), Rotated=(0.3192, -0.1672)
# Dimension 3: Original=(-0.0572, 0.3112), Rotated=(-0.0584, 0.3110)
# Position 5 dimensions:
# Dimension 0: Original=(-0.2113, -0.8669), Rotated=(-0.8913, -0.0433)
# Dimension 1: Original=(-0.4850, 0.7268), Rotated=(-0.7741, 0.4053)
# Dimension 2: Original=(0.4385, -0.0451), Rotated=(0.4402, -0.0231)
# Dimension 3: Original=(1.2229, 1.0233), Rotated=(1.2178, 1.0294)
# Position 6 dimensions:
# Dimension 0: Original=(1.8888, 0.1041), Rotated=(1.8427, -0.4278)
# Dimension 1: Original=(-0.6775, -0.6203), Rotated=(-0.2089, -0.8944)
# Dimension 2: Original=(0.1686, 1.0051), Rotated=(0.1081, 1.0134)
# Dimension 3: Original=(-0.1045, -2.0344), Rotated=(-0.0923, -2.0350)
# Position 7 dimensions:
# Dimension 0: Original=(1.1521, -0.6835), Rotated=(1.3176, 0.2417)
# Dimension 1: Original=(0.1746, -1.0196), Rotated=(0.7904, -0.6673)
# Dimension 2: Original=(0.7366, -1.8264), Rotated=(0.8626, -1.7704)
# Dimension 3: Original=(0.8820, -1.6744), Rotated=(0.8937, -1.6682)
# Position 8 dimensions:
# Dimension 0: Original=(0.4402, 1.3635), Rotated=(-1.4131, 0.2371)
# Dimension 1: Original=(0.2169, -0.6469), Rotated=(0.6151, -0.2951)
# Dimension 2: Original=(-0.4988, -0.2984), Rotated=(-0.4734, -0.3373)
# Dimension 3: Original=(-1.1448, 1.3578), Rotated=(-1.1557, 1.3486)
# Position 9 dimensions:
# Dimension 0: Original=(-1.8282, -0.0289), Rotated=(1.6776, -0.7271)
# Dimension 1: Original=(-1.6605, 0.3599), Rotated=(-1.3141, -1.0770)
# Dimension 2: Original=(0.1228, -1.5638), Rotated=(0.2629, -1.5464)
# Dimension 3: Original=(0.1562, 0.8088), Rotated=(0.1489, 0.8101)
